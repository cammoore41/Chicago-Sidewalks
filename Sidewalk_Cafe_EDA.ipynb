# %% [markdown]
# <a href="https://colab.research.google.com/github/cammoore41/Chicago-Sidewalks/blob/code/Sidewalk_Cafe_EDA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
test

# %%
import numpy as np

# %%
import pandas as pd
cafe_df=pd.read_csv('/content/drive/My Drive/sidewalk-cafe-permits.csv')

# %%
cafe_df.describe()
# Out:
#        PERMIT NUMBER  ACCOUNT NUMBER  ...  Census Tracts         Wards
# count   1.799800e+04    17998.000000  ...   17996.000000  17996.000000
# mean    1.091389e+06   191246.942549  ...     426.160369     30.618749
# std     3.696445e+04   149258.208091  ...     250.330814     11.500412
# min     1.000571e+06       12.000000  ...       1.000000      1.000000
# 25%     1.062466e+06    21100.000000  ...     159.000000     24.000000
# 50%     1.100272e+06   230211.000000  ...     481.000000     36.000000
# 75%     1.121763e+06   327764.000000  ...     665.000000     39.000000
# max     1.142666e+06   463067.000000  ...     799.000000     50.000000
#
# [8 rows x 14 columns]

# %%
cafe_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17998 entries, 0 to 17997
# Data columns (total 29 columns):
# PERMIT NUMBER             17998 non-null int64
# ACCOUNT NUMBER            17998 non-null int64
# SITE NUMBER               17998 non-null int64
# LEGAL NAME                17998 non-null object
# DOING BUSINESS AS NAME    17998 non-null object
# ISSUED DATE               17998 non-null object
# EXPIRATION DATE           17998 non-null object
# PAYMENT DATE              17998 non-null object
# ADDRESS                   17998 non-null object
# ADDRESS NUMBER START      17998 non-null object
# ADDRESS NUMBER            17998 non-null object
# STREET DIRECTION          17998 non-null object
# STREET                    17998 non-null object
# STREET TYPE               16920 non-null object
# CITY                      17998 non-null object
# STATE                     17593 non-null object
# ZIP CODE                  17400 non-null float64
# WARD                      17998 non-null int64
# PRECINCT                  17947 non-null float64
# WARD PRECINCT             17998 non-null object
# POLICE DISTRICT           17963 non-null float64
# LATITUDE                  17996 non-null float64
# LONGITUDE                 17996 non-null float64
# LOCATION                  17996 non-null object
# Community Areas           17996 non-null float64
# Zip Codes                 17996 non-null float64
# Boundaries - ZIP Codes    17996 non-null float64
# Census Tracts             17996 non-null float64
# Wards                     17996 non-null float64
# dtypes: float64(10), int64(4), object(15)
# memory usage: 4.0+ MB

# %%
cafe_df.head(10)
# Out:
#    PERMIT NUMBER  ACCOUNT NUMBER  ...  Census Tracts Wards
# 0        1142666          458934  ...          457.0  19.0
# 1        1142290          294900  ...          564.0  24.0
# 2        1142132          459163  ...          580.0  36.0
# 3        1142101          384478  ...          298.0  40.0
# 4        1142100          456144  ...          548.0  41.0
# 5        1142099          457410  ...          669.0  36.0
# 6        1141644          428117  ...          365.0  26.0
# 7        1141643          458283  ...          387.0  49.0
# 8        1141642          281904  ...          580.0  36.0
# 9        1141641           68427  ...           94.0  50.0
#
# [10 rows x 29 columns]

# %%
cafe_df.tail(10)
# Out:
#        PERMIT NUMBER  ACCOUNT NUMBER  ...  Census Tracts Wards
# 17988        1007406             315  ...          271.0  34.0
# 17989        1007306           67021  ...          481.0  41.0
# 17990        1007265           22568  ...          311.0  19.0
# 17991        1007248          204352  ...          158.0  36.0
# 17992        1004393          205657  ...           92.0  36.0
# 17993        1003612          204664  ...          481.0  41.0
# 17994        1002993              51  ...          158.0  36.0
# 17995        1002652          203574  ...          227.0  28.0
# 17996        1001307          202156  ...           83.0  39.0
# 17997        1000571          201243  ...          652.0  36.0
#
# [10 rows x 29 columns]

# %%
data.keys()
# Out:
# Index(['PERMIT NUMBER', 'ACCOUNT NUMBER', 'SITE NUMBER', 'LEGAL NAME',
#        'DOING BUSINESS AS NAME', 'ISSUED DATE', 'EXPIRATION DATE',
#        'PAYMENT DATE', 'ADDRESS', 'ADDRESS NUMBER START', 'ADDRESS NUMBER',
#        'STREET DIRECTION', 'STREET', 'CITY', 'STATE', 'ZIP CODE', 'WARD',
#        'POLICE DISTRICT', 'Community Areas', 'Issued', 'year', 'month'],
#       dtype='object')

# %%
#Data Dictionary
print('Number of unique permit numbers:',permit.nunique())
print('Number of unique account numbers:',account.nunique(dropna='TRUE'))
print('Site Numbers:',site.unique())
print('Number of legal names:',legname.nunique())
print('Number of business names:',busname.nunique()) 
print('Number of issued dates:',issdate.nunique(dropna='TRUE'))
print('Expiration dates:',expdate.unique())
print('Number of payment dates:',paydate.nunique())
print('Number of addresses:',address.nunique())
print('Street direction:', stdir.unique())
print('Street name:', street.unique())
print('City:',city.unique())
print('State:',state.unique())
print('Zip Code:',zipcode.unique())
print('Ward:',ward.unique())
print('Police District:',police.unique())
#The rest of the variables are not relevant to this project.
# Out:
# Number of unique permit numbers: 17400
# Number of unique account numbers: 2737
# Site Numbers: [  1   4   2   3  58  11   5   7  37   9  10  14  12   6  26   8  34  90
#   20  19  93  21  18  35  84 101  16 178 111  82  15  50 130  17 156 131
#  120  79  38  27  56 112 115  92  48 137  80  54  74 125 158  13  70  44
#   91 134  29  31  39  28  65  24  23  62 110  78 124 173  46 139  42  43
#  105  41 167  77 147  47 161 136 103 164  32  98  66  57  51  55  30  33]
# Number of legal names: 2736
# Number of business names: 2782
# Number of issued dates: 2398
# Expiration dates: ['2020-02-29T00:00:00.000' '2018-12-01T00:00:00.000'
#  '2019-02-28T00:00:00.000' '2018-02-28T00:00:00.000'
#  '2017-12-01T00:00:00.000' '2016-12-01T00:00:00.000'
#  '2015-12-01T00:00:00.000' '2014-12-01T00:00:00.000'
#  '2013-12-01T00:00:00.000' '2012-12-01T00:00:00.000'
#  '2011-12-01T00:00:00.000' '2010-12-01T00:00:00.000'
#  '2009-12-01T00:00:00.000' '2008-12-01T00:00:00.000'
#  '2014-02-10T00:00:00.000' '2007-12-01T00:00:00.000'
#  '2009-02-28T00:00:00.000' '2006-12-01T00:00:00.000'
#  '2005-12-01T00:00:00.000' '2004-11-01T00:00:00.000'
#  '2003-11-01T00:00:00.000' '2002-11-01T00:00:00.000'
#  '2001-11-01T00:00:00.000']
# Number of payment dates: 2323
# Number of addresses: 2456
# Street direction: ['W' 'N' 'S' 'E']
# Street name: ['BELMONT' 'ASHLAND' 'MICHIGAN' 'MILWAUKEE' 'ILLINOIS' 'RACINE' 'ARMITAGE'
#  'LAWRENCE' 'MADISON' 'WELLS' 'DEARBORN' 'STATE' 'BELLEVUE' 'RUSH' 'DAMEN'
#  'LINCOLN' 'SOUTHPORT' 'WESTERN' 'IRVING PARK' 'NEVA' 'HUBBARD' '53RD'
#  'WEBSTER' 'DELAWARE' 'CHICAGO' 'CLARK' 'FULTON MARKET' 'HARPER' 'HURON'
#  'BRYN MAWR' 'CALIFORNIA' 'RANDOLPH' 'BROADWAY' 'HALSTED' 'LAWNDALE'
#  'WRIGHTWOOD' 'LOGAN' 'WABASH' '26TH' 'FULLERTON' 'DEVON' 'CICERO'
#  'DIVISION' 'FRANKLIN' 'INSTITUTE' 'SHEFFIELD' '59TH' 'CLINTON' 'SANGAMON'
#  'TAYLOR' 'WILSON' 'GRAND' 'MONTROSE' 'CLEVELAND' 'PETERSON' 'MCCLURG'
#  'LAKE' 'WACKER' 'LARRABEE' 'WOODLAWN' '51ST' 'DIVERSEY' 'ERIE' 'EWING'
#  'ROOSEVELT' 'AUGUSTA' 'PEARSON' 'WASHINGTON' 'COTTAGE GROVE' 'OAKLEY'
#  'SHERIDAN' 'NORTH' 'MAXWELL' 'ROSCOE' '18TH' '57TH' 'LOYOLA' 'CLYBOURN'
#  'LA SALLE' 'SUPERIOR' 'ARGYLE' 'DAYTON' 'ONTARIO' 'CHESTNUT' 'BERWYN'
#  'BRIAR' 'ADAMS' 'KINZIE' 'WELLINGTON' 'NORTHWEST' 'KEDZIE' '31ST'
#  'CLARENDON' 'BALMORAL' 'GREEN' 'HARLEM' 'FOSTER' 'MONROE' 'VERNON PARK'
#  'HALE' 'SCHOOL' 'MORSE' 'JACKSON' 'CORTLAND' 'OHIO' 'PULASKI' 'OLMSTED'
#  'CERMAK' 'FULTON' 'JARVIS' '33RD' '47TH' 'WALTON' 'GRANVILLE' 'SAWYER'
#  'PLYMOUTH' 'PARNELL' 'CANAL' 'CENTRAL' 'WINNEMAC' '63RD' 'WOLCOTT'
#  'ADDISON' '35TH' 'MANOR' 'OGDEN' 'LAFLIN' 'RAVENSWOOD' 'ROCKWELL'
#  'LEAVITT' 'BELDEN' 'BUENA' 'ABERDEEN' 'INDIANA' 'SEDGWICK' 'SCHUBERT'
#  'LARAMIE' 'WOOD' 'WABANSIA' 'ORLEANS' 'VAN BUREN' 'OLIPHANT' 'MORGAN'
#  'MAPLE' 'JEFFERSON' '8TH' 'TALCOTT' 'GREENVIEW' 'PAULINA' 'CORNELIA'
#  '43RD' 'CITYFRONT PLAZA' 'BISSELL' 'ST CLAIR' 'SUNNYSIDE' 'ST LAWRENCE'
#  'LUNT' 'WINCHESTER' 'ELSTON' 'LINCOLN PARK WEST' 'ELMDALE' 'PRINCETON'
#  'PEORIA' 'HAZEL' 'HOWARD' 'GERMANIA' 'LELAND' 'COMMERCIAL' '21ST'
#  'FAIRBANKS' 'MAPLEWOOD' '87TH' 'ARCHER' 'BYRON' 'NEWPORT' 'WILLOW' 'MAY'
#  'GRACE' 'KINZUA' 'LAKE SHORE' 'CHRISTIANA' 'NOBLE' 'HYDE PARK' 'ELM'
#  'GIDDINGS' '95TH' '69TH' '111TH' 'KOSTNER' 'HIGGINS' 'LAKE SHORE WEST'
#  'LOOMIS' 'CLAREMONT' 'OAK' 'ARTESIAN' 'CEDAR' 'BLUE ISLAND' 'BELL'
#  'DR MARTIN LUTHER KING JR' 'BARRY' 'KINGSBURY' 'AUSTIN' 'COLUMBUS'
#  'RIDGE' 'WALLACE' 'FRANCISCO' 'ORCHARD' 'ALTGELD' 'DICKENS' 'DORCHESTER'
#  'AVERS' 'WEED' 'CAMPBELL' 'HOMEWOOD' 'PACIFIC' 'CONGRESS' '71ST']
# City: ['CHICAGO']
# State: ['IL']
# Zip Code: [60634. 60640. 60601. 60647. 60654. 60608. 60630. 60661. 60611. 60614.
#  60610. 60622. 60657. 60641. 60707. 60615. 60642. 60607. 60660. 60618.
#  60603. 60623. 60606. 60605. 60629. 60625. 60659. 60613. 60639. 60619.
#  60609. 60617. 60616. 60653. 60637. 60602. 60626. 60631. 60643. 60604.
#  60646. 60612. 60638. 60628. 60645. 60656. 60620. 60621. 60655. 60632.
#  60649.]
# Ward: [38 40 42 32  1 25 26 45  2 44 27 29  5 43  4 48 30 22 47  3 16 46 33 39
#  11  8 31 10 35 49 41 19 28 50 13 36  9 12 21  6 14 15 23]
# Police District: [16. 20.  1. 14. 18. 12. 19. 25.  2. 24. 17. 10.  8.  9.  4. 22.  5.  7.
#   3.]

# %%
permit=data['PERMIT NUMBER']
permit.nunique()
# Out:
# 17400

# %%
account=data['ACCOUNT NUMBER']
account.nunique(dropna='TRUE')
# Out:
# 2737

# %%
site=data['SITE NUMBER']
site.nunique(dropna='TRUE')
site.unique()
# Out:
# array([  1,   4,   2,   3,  58,  11,   5,   7,  37,   9,  10,  14,  12,
#          6,  26,   8,  34,  90,  20,  19,  93,  21,  18,  35,  84, 101,
#         16, 178, 111,  82,  15,  50, 130,  17, 156, 131, 120,  79,  38,
#         27,  56, 112, 115,  92,  48, 137,  80,  54,  74, 125, 158,  13,
#         70,  44,  91, 134,  29,  31,  39,  28,  65,  24,  23,  62, 110,
#         78, 124, 173,  46, 139,  42,  43, 105,  41, 167,  77, 147,  47,
#        161, 136, 103, 164,  32,  98,  66,  57,  51,  55,  30,  33])

# %%
data['SITE NUMBER'].value_counts()
# Out:
# 1      12800
# 2       2000
# 3        512
# 4        237
# 5        180
#        ...
# 41         2
# 167        2
# 30         1
# 55         1
# 164        1
# Name: SITE NUMBER, Length: 90, dtype: int64

# %%
sns.boxplot(data['SITE NUMBER'])

# %%
data['SITE NUMBER'].nunique()
# Out:
# 90

# %%
min(data['SITE NUMBER'])
# Out:
# 1

# %%
legname=data['LEGAL NAME']
legname.nunique()
# Out:
# 2736

# %%
busname=data['DOING BUSINESS AS NAME']
busname.nunique()
# Out:
# 2782

# %%
issdate=data['ISSUED DATE']
issdate.nunique(dropna='TRUE')
# Out:
# 2398

# %%
expdate=data['EXPIRATION DATE']
expdate.unique()
# Out:
# array(['2020-02-29T00:00:00.000', '2018-12-01T00:00:00.000',
#        '2019-02-28T00:00:00.000', '2018-02-28T00:00:00.000',
#        '2017-12-01T00:00:00.000', '2016-12-01T00:00:00.000',
#        '2015-12-01T00:00:00.000', '2014-12-01T00:00:00.000',
#        '2013-12-01T00:00:00.000', '2012-12-01T00:00:00.000',
#        '2011-12-01T00:00:00.000', '2010-12-01T00:00:00.000',
#        '2009-12-01T00:00:00.000', '2008-12-01T00:00:00.000',
#        '2014-02-10T00:00:00.000', '2007-12-01T00:00:00.000',
#        '2009-02-28T00:00:00.000', '2006-12-01T00:00:00.000',
#        '2005-12-01T00:00:00.000', '2004-11-01T00:00:00.000',
#        '2003-11-01T00:00:00.000', '2002-11-01T00:00:00.000',
#        '2001-11-01T00:00:00.000'], dtype=object)

# %%
paydate=data['PAYMENT DATE']
paydate.nunique()
# Out:
# 2323

# %%
address=data['ADDRESS']
address.nunique()
# Out:
# 2456

# %%
addressnum=data['ADDRESS NUMBER']
addressnum.nunique()
# Out:
# 1835

# %%
stdir=data['STREET DIRECTION']
stdir.unique()
# Out:
# array(['W', 'N', 'S', 'E'], dtype=object)

# %%
street=data['STREET']
street.unique()
# Out:
# array(['BELMONT', 'ASHLAND', 'MICHIGAN', 'MILWAUKEE', 'ILLINOIS',
#        'RACINE', 'ARMITAGE', 'LAWRENCE', 'MADISON', 'WELLS', 'DEARBORN',
#        'STATE', 'BELLEVUE', 'RUSH', 'DAMEN', 'LINCOLN', 'SOUTHPORT',
#        'WESTERN', 'IRVING PARK', 'NEVA', 'HUBBARD', '53RD', 'WEBSTER',
#        'DELAWARE', 'CHICAGO', 'CLARK', 'FULTON MARKET', 'HARPER', 'HURON',
#        'BRYN MAWR', 'CALIFORNIA', 'RANDOLPH', 'BROADWAY', 'HALSTED',
#        'LAWNDALE', 'WRIGHTWOOD', 'LOGAN', 'WABASH', '26TH', 'FULLERTON',
#        'DEVON', 'CICERO', 'DIVISION', 'FRANKLIN', 'INSTITUTE',
#        'SHEFFIELD', '59TH', 'CLINTON', 'SANGAMON', 'TAYLOR', 'WILSON',
#        'GRAND', 'MONTROSE', 'CLEVELAND', 'PETERSON', 'MCCLURG', 'LAKE',
#        'WACKER', 'LARRABEE', 'WOODLAWN', '51ST', 'DIVERSEY', 'ERIE',
#        'EWING', 'ROOSEVELT', 'AUGUSTA', 'PEARSON', 'WASHINGTON',
#        'COTTAGE GROVE', 'OAKLEY', 'SHERIDAN', 'NORTH', 'MAXWELL',
#        'ROSCOE', '18TH', '57TH', 'LOYOLA', 'CLYBOURN', 'LA SALLE',
#        'SUPERIOR', 'ARGYLE', 'DAYTON', 'ONTARIO', 'CHESTNUT', 'BERWYN',
#        'BRIAR', 'ADAMS', 'KINZIE', 'WELLINGTON', 'NORTHWEST', 'KEDZIE',
#        '31ST', 'CLARENDON', 'BALMORAL', 'GREEN', 'HARLEM', 'FOSTER',
#        'MONROE', 'VERNON PARK', 'HALE', 'SCHOOL', 'MORSE', 'JACKSON',
#        'CORTLAND', 'OHIO', 'PULASKI', 'OLMSTED', 'CERMAK', 'FULTON',
#        'JARVIS', '33RD', '47TH', 'WALTON', 'GRANVILLE', 'SAWYER',
#        'PLYMOUTH', 'PARNELL', 'CANAL', 'CENTRAL', 'WINNEMAC', '63RD',
#        'WOLCOTT', 'ADDISON', '35TH', 'MANOR', 'OGDEN', 'LAFLIN',
#        'RAVENSWOOD', 'ROCKWELL', 'LEAVITT', 'BELDEN', 'BUENA', 'ABERDEEN',
#        'INDIANA', 'SEDGWICK', 'SCHUBERT', 'LARAMIE', 'WOOD', 'WABANSIA',
#        'ORLEANS', 'VAN BUREN', 'OLIPHANT', 'MORGAN', 'MAPLE', 'JEFFERSON',
#        '8TH', 'TALCOTT', 'GREENVIEW', 'PAULINA', 'CORNELIA', '43RD',
#        'CITYFRONT PLAZA', 'BISSELL', 'ST CLAIR', 'SUNNYSIDE',
#        'ST LAWRENCE', 'LUNT', 'WINCHESTER', 'ELSTON', 'LINCOLN PARK WEST',
#        'ELMDALE', 'PRINCETON', 'PEORIA', 'HAZEL', 'HOWARD', 'GERMANIA',
#        'LELAND', 'COMMERCIAL', '21ST', 'FAIRBANKS', 'MAPLEWOOD', '87TH',
#        'ARCHER', 'BYRON', 'NEWPORT', 'WILLOW', 'MAY', 'GRACE', 'KINZUA',
#        'LAKE SHORE', 'CHRISTIANA', 'NOBLE', 'HYDE PARK', 'ELM',
#        'GIDDINGS', '95TH', '69TH', '111TH', 'KOSTNER', 'HIGGINS',
#        'LAKE SHORE WEST', 'LOOMIS', 'CLAREMONT', 'OAK', 'ARTESIAN',
#        'CEDAR', 'BLUE ISLAND', 'BELL', 'DR MARTIN LUTHER KING JR',
#        'BARRY', 'KINGSBURY', 'AUSTIN', 'COLUMBUS', 'RIDGE', 'WALLACE',
#        'FRANCISCO', 'ORCHARD', 'ALTGELD', 'DICKENS', 'DORCHESTER',
#        'AVERS', 'WEED', 'CAMPBELL', 'HOMEWOOD', 'PACIFIC', 'CONGRESS',
#        '71ST'], dtype=object)

# %%
street.nunique()
# Out:
# 217

# %%
city=data['CITY']
city.unique()
# Out:
# array(['CHICAGO'], dtype=object)

# %%
state=data['STATE']
state.unique()
# Out:
# array(['IL'], dtype=object)

# %%
zipcode=data['ZIP CODE']
zipcode.unique()
# Out:
# array([60634., 60640., 60601., 60647., 60654., 60608., 60630., 60661.,
#        60611., 60614., 60610., 60622., 60657., 60641., 60707., 60615.,
#        60642., 60607., 60660., 60618., 60603., 60623., 60606., 60605.,
#        60629., 60625., 60659., 60613., 60639., 60619., 60609., 60617.,
#        60616., 60653., 60637., 60602., 60626., 60631., 60643., 60604.,
#        60646., 60612., 60638., 60628., 60645., 60656., 60620., 60621.,
#        60655., 60632., 60649.])

# %%
zipcode.nunique()
# Out:
# 51

# %%
ward=data['WARD']
ward.unique()
# Out:
# array([38, 40, 42, 32,  1, 25, 26, 45,  2, 44, 27, 29,  5, 43,  4, 48, 30,
#        22, 47,  3, 16, 46, 33, 39, 11,  8, 31, 10, 35, 49, 41, 19, 28, 50,
#        13, 36,  9, 12, 21,  6, 14, 15, 23])

# %%
ward.nunique()
# Out:
# 43

# %%
police=data['POLICE DISTRICT']
police.unique()
# Out:
# array([16., 20.,  1., 14., 18., 12., 19., 25.,  2., 24., 17., 10.,  8.,
#         9.,  4., 22.,  5.,  7.,  3.])

# %%
community=data['Community Areas']
community.unique()
# Out:
# array([17., 76., 38., 25., 23., 37., 33., 15., 29., 68., 57., 26.,  8.,
#        22., 32., 34., 46., 61.,  6., 31., 16., 13., 19., 58., 41., 59.,
#        49.,  2., 10., 14., 20., 77., 74., 11., 35.,  4., 21., 62., 60.,
#        36.,  5., 47., 63., 64., 18., 48.,  1., 70., 42., 12., 24., 71.,
#        66., 73., 55., 56., 39.])

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 17400 entries, 0 to 17997
# Data columns (total 22 columns):
# PERMIT NUMBER             17400 non-null int64
# ACCOUNT NUMBER            17400 non-null int64
# SITE NUMBER               17400 non-null int64
# LEGAL NAME                17400 non-null object
# DOING BUSINESS AS NAME    17400 non-null object
# ISSUED DATE               17400 non-null object
# EXPIRATION DATE           17400 non-null object
# PAYMENT DATE              17400 non-null object
# ADDRESS                   17400 non-null object
# ADDRESS NUMBER START      17400 non-null object
# ADDRESS NUMBER            17400 non-null object
# STREET DIRECTION          17400 non-null object
# STREET                    17400 non-null object
# CITY                      17400 non-null object
# STATE                     17400 non-null object
# ZIP CODE                  17400 non-null float64
# WARD                      17400 non-null int64
# POLICE DISTRICT           17400 non-null float64
# Community Areas           17400 non-null float64
# Issued                    17400 non-null datetime64[ns]
# year                      17400 non-null int64
# month                     17400 non-null int64
# dtypes: datetime64[ns](1), float64(3), int64(6), object(12)
# memory usage: 3.1+ MB

# %% [markdown]
# ### Report on the quality of the data.

# %%
#dropping columns that aren't relevant for the purpose of this EDA
new_cafe=cafe_df.drop(columns=['STREET TYPE','LATITUDE','LONGITUDE','LOCATION','Zip Codes','Boundaries - ZIP Codes','Census Tracts','ADDRESS NUMBER START','Wards', 'PRECINCT','WARD PRECINCT','Community Areas'])

# %% [markdown]
# There were ten columns dropped due to irrelevance.

# %%
new_cafe.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17998 entries, 0 to 17997
# Data columns (total 17 columns):
# PERMIT NUMBER             17998 non-null int64
# ACCOUNT NUMBER            17998 non-null int64
# SITE NUMBER               17998 non-null int64
# LEGAL NAME                17998 non-null object
# DOING BUSINESS AS NAME    17998 non-null object
# ISSUED DATE               17998 non-null object
# EXPIRATION DATE           17998 non-null object
# PAYMENT DATE              17998 non-null object
# ADDRESS                   17998 non-null object
# ADDRESS NUMBER            17998 non-null object
# STREET DIRECTION          17998 non-null object
# STREET                    17998 non-null object
# CITY                      17998 non-null object
# STATE                     17593 non-null object
# ZIP CODE                  17400 non-null float64
# WARD                      17998 non-null int64
# POLICE DISTRICT           17963 non-null float64
# dtypes: float64(2), int64(4), object(11)
# memory usage: 2.3+ MB

# %% [markdown]
# There is missing data in 'State', 'Zip Code', 'Police District', and 'Community Areas'. There is the most missing data in Zip Code so I will drop the data points that are missing this. I want to focus on zip code as part of my analysis, so this variable is important. It is also a set value that can't be imputed. If I had time, I could fill all of this missing data in, based on the address.

# %%
new_cafe_2=new_cafe.dropna(subset=['ZIP CODE'])

# %%
new_cafe_2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 17400 entries, 0 to 17997
# Data columns (total 17 columns):
# PERMIT NUMBER             17400 non-null int64
# ACCOUNT NUMBER            17400 non-null int64
# SITE NUMBER               17400 non-null int64
# LEGAL NAME                17400 non-null object
# DOING BUSINESS AS NAME    17400 non-null object
# ISSUED DATE               17400 non-null object
# EXPIRATION DATE           17400 non-null object
# PAYMENT DATE              17400 non-null object
# ADDRESS                   17400 non-null object
# ADDRESS NUMBER            17400 non-null object
# STREET DIRECTION          17400 non-null object
# STREET                    17400 non-null object
# CITY                      17400 non-null object
# STATE                     16999 non-null object
# ZIP CODE                  17400 non-null float64
# WARD                      17400 non-null int64
# POLICE DISTRICT           17400 non-null float64
# dtypes: float64(2), int64(4), object(11)
# memory usage: 2.4+ MB

# %% [markdown]
# It looks like we now have 17400 entries for each variable, except 'State', which is missing 1 value. We know that all of these data points are from Chicago, which is in Illinois, so we can fill in this missing value.

# %%
new_cafe_2.loc[:,('STATE')]=new_cafe_2.loc[:,('STATE')].replace(np.nan, 'IL')
# Out:
# /usr/local/lib/python3.6/dist-packages/pandas/core/indexing.py:494: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[item] = s

# %%
new_cafe_2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 17400 entries, 0 to 17997
# Data columns (total 19 columns):
# PERMIT NUMBER             17400 non-null int64
# ACCOUNT NUMBER            17400 non-null int64
# SITE NUMBER               17400 non-null int64
# LEGAL NAME                17400 non-null object
# DOING BUSINESS AS NAME    17400 non-null object
# ISSUED DATE               17400 non-null object
# EXPIRATION DATE           17400 non-null object
# PAYMENT DATE              17400 non-null object
# ADDRESS                   17400 non-null object
# ADDRESS NUMBER START      17400 non-null object
# ADDRESS NUMBER            17400 non-null object
# STREET DIRECTION          17400 non-null object
# STREET                    17400 non-null object
# CITY                      17400 non-null object
# STATE                     17400 non-null object
# ZIP CODE                  17400 non-null float64
# WARD                      17400 non-null int64
# POLICE DISTRICT           17400 non-null float64
# Community Areas           17400 non-null float64
# dtypes: float64(3), int64(4), object(12)
# memory usage: 2.7+ MB

# %%
st=new_cafe_2['STATE']
st.unique()
# Out:
# array(['IL'], dtype=object)

# %% [markdown]
# There are no duplicated rows in this dataset.

# %%
new_cafe_2.duplicated().sum()
# Out:
# 0

# %%
new_cafe_2.describe()
# Out:
#        PERMIT NUMBER  ACCOUNT NUMBER  ...  POLICE DISTRICT  Community Areas
# count   1.740000e+04    17400.000000  ...     17400.000000     17400.000000
# mean    1.091186e+06   191179.296149  ...        14.633218        39.527874
# std     3.685197e+04   149165.004412  ...         6.504983        16.874471
# min     1.000571e+06       12.000000  ...         1.000000         1.000000
# 25%     1.062566e+06    21237.000000  ...        12.000000        29.000000
# 50%     1.100142e+06   230211.000000  ...        18.000000        37.000000
# 75%     1.121653e+06   326675.000000  ...        19.000000        57.000000
# max     1.142666e+06   463067.000000  ...        25.000000        77.000000
#
# [8 rows x 7 columns]

# %%
new_cafe_2[new_cafe_2.STREET=='BRIAR']
# Out:
#      PERMIT NUMBER  ACCOUNT NUMBER  ...  POLICE DISTRICT Community Areas
# 270        1139687          432547  ...             19.0            57.0
#
# [1 rows x 19 columns]

# %%
data=new_cafe_2

# %%
data
# Out:
#        PERMIT NUMBER  ACCOUNT NUMBER  ...  POLICE DISTRICT Community Areas
# 0            1142666          458934  ...             16.0            17.0
# 1            1142290          294900  ...             20.0            76.0
# 2            1142132          459163  ...              1.0            38.0
# 3            1142101          384478  ...             14.0            25.0
# 4            1142100          456144  ...             14.0            23.0
# ...              ...             ...  ...              ...             ...
# 17993        1003612          204664  ...             14.0            25.0
# 17994        1002993              51  ...             18.0            37.0
# 17995        1002652          203574  ...             10.0            32.0
# 17996        1001307          202156  ...             19.0            57.0
# 17997        1000571          201243  ...             18.0            37.0
#
# [17400 rows x 19 columns]

# %%
data['PERMIT NUMBER'].unique().size
# Out:
# 17400

# %%
data['ACCOUNT NUMBER'].size
# Out:
# 17400

# %%
data['ACCOUNT NUMBER'].unique().size
# Out:
# 2737

# %% [markdown]
# So we know that there are 17400 unique permit numbers that were filed since 2001, but only 2737 different account numbers associated with those filings.

# %%
data['LEGAL NAME'].unique().size
# Out:
# 2736

# %% [markdown]
# There's one less unique legal name than there is account number. Which company was this? Did they change their account number?

# %%
newdf=data.loc[:, ['ACCOUNT NUMBER', 'LEGAL NAME']]

# %%
newdfdrop=newdf.drop_duplicates()

# %%
newname=newdfdrop.loc[:, ['LEGAL NAME']]

# %%
newname
# Out:
#                                   LEGAL NAME
# 0                         TINTO & TAPAS, LLC
# 1                              PIE CAFE, LLC
# 2      KALIFLOWER 333 NORTH MICHIGAN AVE LLC
# 3            1732 N MILWAUKEE RESTAURANT LLC
# 4                     THE WHALE CHICAGO, LLC
# ...                                      ...
# 17937                I BAGINSKI & L MASLANKA
# 17940               KATMANDU CREATIONS, INC.
# 17949                  TOUR MERLE GROUP LCC.
# 17951                    WELLS KITCHEN CORP.
# 17958                    EATING PLACES, INC.
#
# [2737 rows x 1 columns]

# %%
duplicateRowsDF = newname[newname.duplicated()]
 
print("Duplicate Rows except first occurrence based on all columns are :")
print(duplicateRowsDF)
# Out:
# Duplicate Rows except first occurrence based on all columns are :
#             LEGAL NAME
# 12374  ABP CORPORATION

# %%
data[data['LEGAL NAME']=='ABP CORPORATION']
# Out:
#        PERMIT NUMBER  ACCOUNT NUMBER  ...  POLICE DISTRICT Community Areas
# 2183         1131411          337253  ...              1.0            38.0
# 3506         1125998          337253  ...              1.0            38.0
# 3784         1123150          337253  ...              1.0            38.0
# 5771         1117128          337253  ...              1.0            38.0
# 7031         1111086          337253  ...              1.0            38.0
# 7039         1111077          337253  ...              1.0            38.0
# 7763         1105343          337253  ...              1.0            38.0
# 7876         1105202          337253  ...              1.0            38.0
# 7879         1105199          337253  ...              1.0            38.0
# 9299         1099694          337253  ...              1.0            38.0
# 9425         1099498          337253  ...              1.0            38.0
# 9426         1099497          337253  ...              1.0            38.0
# 10431        1095006          337253  ...              1.0            38.0
# 10447        1094987          337253  ...              1.0            38.0
# 10472        1094959          337253  ...              1.0            38.0
# 11332        1090097          337253  ...              1.0            38.0
# 11438        1089929          337253  ...              1.0            38.0
# 11439        1089928          337253  ...              1.0            38.0
# 12374        1085588          207993  ...              1.0            38.0
# 12375        1085587          207993  ...              1.0            38.0
# 12420        1085331          207993  ...              1.0            38.0
# 12586        1075852          207993  ...              1.0            38.0
# 13290        1071611          207993  ...              1.0            38.0
# 13291        1071585          207993  ...              1.0            38.0
# 13757        1061383          207993  ...              1.0            38.0
# 13948        1060595          207993  ...              1.0            38.0
# 14022        1060452          207993  ...              1.0            38.0
# 14510        1050338          207993  ...              1.0            38.0
# 14829        1048707          207993  ...              1.0            38.0
# 14831        1048697          207993  ...              1.0            38.0
# 15519        1041816          207993  ...              1.0            38.0
# 15521        1041814          207993  ...              1.0            38.0
# 15587        1041262          207993  ...              1.0            38.0
# 15869        1033557          207993  ...              1.0            38.0
# 15871        1033553          207993  ...              1.0            38.0
# 16051        1033070          207993  ...              1.0            38.0
# 16821        1025379          207993  ...              1.0            38.0
# 16836        1025329          207993  ...              1.0            38.0
# 16842        1025319          207993  ...              1.0            38.0
# 16847        1025313          207993  ...              1.0            38.0
# 17408        1016052          207993  ...              1.0            38.0
# 17409        1016051          207993  ...              1.0            38.0
# 17410        1016049          207993  ...              1.0            38.0
# 17411        1016047          207993  ...              1.0            38.0
# 17413        1016041          207993  ...              1.0            38.0
# 17417        1016037          207993  ...              1.0            38.0
# 17909        1008297          207993  ...              1.0            38.0
# 17911        1008288          207993  ...              1.0            38.0
# 17913        1008254          207993  ...              1.0            38.0
# 17914        1008252          207993  ...              1.0            38.0
# 17915        1008251          207993  ...              1.0            38.0
#
# [51 rows x 19 columns]

# %% [markdown]
# Mystery solved! For some reason, ABP Corporation switched account numbers in 2010 from 207993 to 337253.

# %%
data['DOING BUSINESS AS NAME'].unique().size
# Out:
# 2782

# %% [markdown]
# There are 2782 business names, and only 2736 legal names. Let's figure this one out too!

# %%
new1df=data.loc[:, ['LEGAL NAME','DOING BUSINESS AS NAME']]

# %%
new1df
# Out:
#                                   LEGAL NAME       DOING BUSINESS AS NAME
# 0                         TINTO & TAPAS, LLC                TINTO & TAPAS
# 1                              PIE CAFE, LLC                     Pie cafe
# 2      KALIFLOWER 333 NORTH MICHIGAN AVE LLC                   KALIFLOWER
# 3            1732 N MILWAUKEE RESTAURANT LLC                 SMALL CHEVAL
# 4                     THE WHALE CHICAGO, LLC            THE WHALE CHICAGO
# ...                                      ...                          ...
# 17993                 A PITZALLA BLUES, INC.               THE REVEL ROOM
# 17994                   152 E. ONTARIO CORP.         O'NEIL'S BAR & GRILL
# 17995                         cafe mauro inc                   CAFE MAURO
# 17996                 Rick's Cafe-Casablanca       Rick's Cafe-Casablanca
# 17997                 THE 5 BOROUGHSDELI LLC  THE 5 BOROUGHS DELICATESSEN
#
# [17400 rows x 2 columns]

# %%
new1dfdrop=new1df.drop_duplicates()

# %%
new1dfdrop
# Out:
#                                   LEGAL NAME   DOING BUSINESS AS NAME
# 0                         TINTO & TAPAS, LLC            TINTO & TAPAS
# 1                              PIE CAFE, LLC                 Pie cafe
# 2      KALIFLOWER 333 NORTH MICHIGAN AVE LLC               KALIFLOWER
# 3            1732 N MILWAUKEE RESTAURANT LLC             SMALL CHEVAL
# 4                     THE WHALE CHICAGO, LLC        THE WHALE CHICAGO
# ...                                      ...                      ...
# 17937                I BAGINSKI & L MASLANKA      EUROPEAN SUNNY CAFE
# 17940               KATMANDU CREATIONS, INC.                    FUZIO
# 17949                  TOUR MERLE GROUP LCC.  BISTROT ZINC/ CAFE ZINC
# 17951                    WELLS KITCHEN CORP.              HUDSON CLUB
# 17958                    EATING PLACES, INC.          ECHO RESTAURANT
#
# [2961 rows x 2 columns]

# %% [markdown]
# This was unexpected! Why are there 2961 rows? I was expecting 2782.

# %%
newname1=new1dfdrop.loc[:, ['LEGAL NAME']]

# %%
newname1
# Out:
#                                   LEGAL NAME
# 0                         TINTO & TAPAS, LLC
# 1                              PIE CAFE, LLC
# 2      KALIFLOWER 333 NORTH MICHIGAN AVE LLC
# 3            1732 N MILWAUKEE RESTAURANT LLC
# 4                     THE WHALE CHICAGO, LLC
# ...                                      ...
# 17937                I BAGINSKI & L MASLANKA
# 17940               KATMANDU CREATIONS, INC.
# 17949                  TOUR MERLE GROUP LCC.
# 17951                    WELLS KITCHEN CORP.
# 17958                    EATING PLACES, INC.
#
# [2961 rows x 1 columns]

# %%
duplicateRowsDF = newname1[newname1.duplicated()]
 
print("Duplicate Rows except first occurrence based on all columns are :")
duplicateRowsDF
# Out:
# Duplicate Rows except first occurrence based on all columns are :
#                            LEGAL NAME
# 32       JOE & THE JUICE ILLINOIS LLC
# 127            THE VEGGIE GRILL, INC.
# 138    FOXTROT VENTURES, INCORPORATED
# 147          GHIRARDELLI CHOCOLATE CO
# 368                CAFFE UMBRIA, INC.
# ...                               ...
# 17163               CALO LOUNGE, INC.
# 17261                  SALPICON, INC.
# 17444        BOUDIN INTERNATIONAL INC
# 17489                VIA VENETO, INC.
# 17724    CARIBOU COFFEE COMPANY, INC.
#
# [225 rows x 1 columns]

# %%
newname2=new1dfdrop.loc[:, ['DOING BUSINESS AS NAME']]

# %%
newname2
# Out:
#         DOING BUSINESS AS NAME
# 0                TINTO & TAPAS
# 1                     Pie cafe
# 2                   KALIFLOWER
# 3                 SMALL CHEVAL
# 4            THE WHALE CHICAGO
# ...                        ...
# 17937      EUROPEAN SUNNY CAFE
# 17940                    FUZIO
# 17949  BISTROT ZINC/ CAFE ZINC
# 17951              HUDSON CLUB
# 17958          ECHO RESTAURANT
#
# [2961 rows x 1 columns]

# %%
duplicateRowsDF = newname2[newname2.duplicated()]
 
print("Duplicate Rows except first occurrence based on all columns are :")
print(duplicateRowsDF)
# Out:
# Duplicate Rows except first occurrence based on all columns are :
#       DOING BUSINESS AS NAME
# 67                  ARGO TEA
# 94                  PASTORAL
# 242           5411 EMPANADAS
# 284            FURIOUS SPOON
# 285            FURIOUS SPOON
# ...                      ...
# 16691   QUIZNOS CLASSIC SUBS
# 16953                 SUBWAY
# 17013            TACO FRESCO
# 17075      SUBWAY SANDWICHES
# 17645          QUIZNO'S SUBS
#
# [179 rows x 1 columns]

# %%
225-179
# Out:
# 46

# %%
2782-2736
# Out:
# 46

# %% [markdown]
# From a quick look, it seems that the duplicates are all chains, or businesses that have multiple locations. For example, Quizno's Changes from Quiznos Classic Subs to Quizno's Subs. Let's do a little more exploration.

# %%
new1dfdrop
# Out:
#                                   LEGAL NAME   DOING BUSINESS AS NAME
# 0                         TINTO & TAPAS, LLC            TINTO & TAPAS
# 1                              PIE CAFE, LLC                 Pie cafe
# 2      KALIFLOWER 333 NORTH MICHIGAN AVE LLC               KALIFLOWER
# 3            1732 N MILWAUKEE RESTAURANT LLC             SMALL CHEVAL
# 4                     THE WHALE CHICAGO, LLC        THE WHALE CHICAGO
# ...                                      ...                      ...
# 17937                I BAGINSKI & L MASLANKA      EUROPEAN SUNNY CAFE
# 17940               KATMANDU CREATIONS, INC.                    FUZIO
# 17949                  TOUR MERLE GROUP LCC.  BISTROT ZINC/ CAFE ZINC
# 17951                    WELLS KITCHEN CORP.              HUDSON CLUB
# 17958                    EATING PLACES, INC.          ECHO RESTAURANT
#
# [2961 rows x 2 columns]

# %%
new1dfdrop[new1dfdrop['DOING BUSINESS AS NAME']=='FURIOUS SPOON']
# Out:
#                           LEGAL NAME DOING BUSINESS AS NAME
# 283  FURIOUS SPOON ANDERSONVILLE LLC          FURIOUS SPOON
# 284   FURIOUS SPOON LOGAN SQUARE LLC          FURIOUS SPOON
# 285                FURIOUS SPOON LLC          FURIOUS SPOON

# %%
new1dfdrop[new1dfdrop['DOING BUSINESS AS NAME']=='SUBWAY']
# Out:
#                             LEGAL NAME DOING BUSINESS AS NAME
# 92                  KARIM & ZUBE, INC.                 SUBWAY
# 776        SHREE HARI INVESTMENT, INC.                 SUBWAY
# 1324                ALEX N ALPESH INC.                 SUBWAY
# 3428                       VJ SUB INC.                 SUBWAY
# 3834   WABASH STREET DEVELOPMENT, INC.                 SUBWAY
# 6433          CAMERON ENTERPRISES, LLC                 SUBWAY
# 9066              PKI SANDWICHES, INC.                 SUBWAY
# 9642                  KULU-MANALI INC.                 SUBWAY
# 9819                     NOOR RUKH LLC                 SUBWAY
# 15671            ENCOMPASS CORPORATION                 SUBWAY
# 15858                  SHANA GROUP INC                 SUBWAY
# 15860            WELLS ENTERPRISES INC                 SUBWAY
# 16287           DANNY & GENIE SONG INC                 SUBWAY
# 16687         CONGRESS ENTERPRISES INC                 SUBWAY
# 16953          NORTH & WELLS ENT. INC.                 SUBWAY

# %%
new1dfdrop[new1dfdrop['DOING BUSINESS AS NAME']=='QUIZNOS CLASSIC SUBS']
# Out:
#                            LEGAL NAME DOING BUSINESS AS NAME
# 16281  M & C PERFECT CONNECTIONS INC.   QUIZNOS CLASSIC SUBS
# 16691                     BENQUIN INC   QUIZNOS CLASSIC SUBS

# %%
new1dfdrop[new1dfdrop['LEGAL NAME']=='FOXTROT VENTURES, INCORPORATED']
# Out:
#                          LEGAL NAME DOING BUSINESS AS NAME
# 21   FOXTROT VENTURES, INCORPORATED         FOXTROT MARKET
# 138  FOXTROT VENTURES, INCORPORATED  THE MARKET BY FOXTROT

# %%
data[data['LEGAL NAME']=='FOXTROT VENTURES, INCORPORATED']
# Out:
#       PERMIT NUMBER  ACCOUNT NUMBER  ...  POLICE DISTRICT Community Areas
# 21          1141396          392906  ...             18.0            37.0
# 138         1140272          392906  ...             19.0            57.0
# 229         1139741          392906  ...             18.0            37.0
# 248         1139722          392906  ...             18.0            37.0
# 306         1139614          392906  ...             18.0            68.0
# 307         1139613          392906  ...             14.0            25.0
# 308         1139612          392906  ...             12.0            29.0
# 1260        1133720          392906  ...             18.0            68.0
# 1424        1133104          392906  ...             12.0            29.0
# 1432        1133082          392906  ...             18.0            37.0
# 1433        1133081          392906  ...             14.0            25.0
# 2769        1127267          392906  ...             12.0            29.0
#
# [12 rows x 19 columns]

# %%
new1dfdrop[new1dfdrop['LEGAL NAME']=='THE VEGGIE GRILL, INC.']
# Out:
#                  LEGAL NAME DOING BUSINESS AS NAME
# 39   THE VEGGIE GRILL, INC.           VEGGIE GRILL
# 127  THE VEGGIE GRILL, INC.       THE VEGGIE GRILL

# %%
new1dfdrop[new1dfdrop['LEGAL NAME']=='VIA VENETO, INC.']
# Out:
#              LEGAL NAME DOING BUSINESS AS NAME
# 557    VIA VENETO, INC.             VIA VENETO
# 17489  VIA VENETO, INC.  VIA VENETO RESTAURANT

# %%
data[data['LEGAL NAME']=='VIA VENETO, INC.']
# Out:
#        PERMIT NUMBER  ACCOUNT NUMBER  ...  POLICE DISTRICT Community Areas
# 557          1139001            5350  ...             17.0            13.0
# 1632         1132550            5350  ...             17.0            13.0
# 2807         1127152            5350  ...             17.0            13.0
# 4306         1122095            5350  ...             17.0            13.0
# 5394         1117739            5350  ...             17.0            13.0
# 6640         1111857            5350  ...             17.0            13.0
# 7674         1105668            5350  ...             17.0            13.0
# 8855         1100695            5350  ...             17.0            13.0
# 10380        1095086            5350  ...             17.0            13.0
# 11448        1089901            5350  ...             17.0            13.0
# 12411        1085498            5350  ...             17.0            13.0
# 13057        1073344            5350  ...             17.0            13.0
# 13859        1060720            5350  ...             17.0            13.0
# 14850        1048483            5350  ...             17.0            13.0
# 15589        1041246            5350  ...             17.0            13.0
# 16277        1032409            5350  ...             17.0            13.0
# 16779        1025446            5350  ...             17.0            13.0
# 17080        1017569            5350  ...             17.0            13.0
# 17489        1015775            5350  ...             17.0            13.0
# 17948        1008132            5350  ...             17.0            13.0
#
# [20 rows x 19 columns]

# %% [markdown]
# Upon further inspection, the franchise restaurants seem to be owned by different companies. There are other local companies that have multiple locations that are called different names. For example, Foxtrot Ventures Inc. has multiple locations named The Market by Foxtrot. But their newest location in Old Town is called Foxtrot Market (where I often study!). It seems that in other cases, the restaurant changed locations and names. Via Veneto Restaurant on 3449 W Peterson Ave seemed to move locations to 6340 N Lincoln Ave in 2002, at which point they changed their name to Via Veneto.

# %%
data[data['LEGAL NAME']=='THE CHICAGO CHOCOLATE COMPANY, INC.']
# Out:
#        PERMIT NUMBER  ACCOUNT NUMBER  ...  POLICE DISTRICT Community Areas
# 14659        1049602          271734  ...             12.0            29.0
# 15309        1042467          271734  ...             12.0            29.0
#
# [2 rows x 19 columns]

# %% [markdown]
# Just for fun, this was my Dad's company years ago^ :)

# %%
data["Issued"]=pd.to_datetime(data['ISSUED DATE'])
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
data["Issued"]
# Out:
# 0       2019-11-25
# 1       2019-10-15
# 2       2019-09-20
# 3       2019-09-20
# 4       2019-09-19
#            ...
# 17993   2001-08-01
# 17994   2001-04-04
# 17995   2001-05-07
# 17996   2001-06-18
# 17997   2001-04-03
# Name: Issued, Length: 17400, dtype: datetime64[ns]

# %%
data['year'] = pd.DatetimeIndex(data['Issued']).year
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
data
# Out:
#        PERMIT NUMBER  ACCOUNT NUMBER  SITE NUMBER  ...     Issued  year month
# 0            1142666          458934            1  ... 2019-11-25  2019    11
# 1            1142290          294900            4  ... 2019-10-15  2019    10
# 2            1142132          459163            1  ... 2019-09-20  2019     9
# 3            1142101          384478            1  ... 2019-09-20  2019     9
# 4            1142100          456144            1  ... 2019-09-19  2019     9
# ...              ...             ...          ...  ...        ...   ...   ...
# 17993        1003612          204664            1  ... 2001-08-01  2001     8
# 17994        1002993              51            1  ... 2001-04-04  2001     4
# 17995        1002652          203574            1  ... 2001-05-07  2001     5
# 17996        1001307          202156            1  ... 2001-06-18  2001     6
# 17997        1000571          201243            1  ... 2001-04-03  2001     4
#
# [17400 rows x 22 columns]

# %%
data['year']
# Out:
# 0        2019
# 1        2019
# 2        2019
# 3        2019
# 4        2019
#          ...
# 17993    2001
# 17994    2001
# 17995    2001
# 17996    2001
# 17997    2001
# Name: year, Length: 17400, dtype: int64

# %%
import seaborn as sns
sns.distplot(data['year'])

# %%
zips=data['ZIP CODE'].unique()

# %%
type(zips)
# Out:
# numpy.ndarray

# %%
for zip in zips:
  print(zip)
  print(data[data['ZIP CODE']==zip]['year'].value_counts())
# Out:
# 60634.0
# 2019    11
# 2016    10
# 2009     9
# 2010     9
# 2015     8
# 2014     8
# 2013     8
# 2012     8
# 2011     8
# 2018     8
# 2017     8
# 2008     6
# 2007     6
# 2006     5
# 2005     5
# 2004     4
# 2003     3
# 2001     3
# 2002     2
# Name: year, dtype: int64
# 60640.0
# 2018    49
# 2017    46
# 2019    45
# 2012    45
# 2016    43
# 2014    43
# 2011    43
# 2013    39
# 2015    38
# 2009    37
# 2008    36
# 2010    36
# 2007    32
# 2006    31
# 2004    27
# 2005    25
# 2003    24
# 2002    17
# 2001    13
# Name: year, dtype: int64
# 60601.0
# 2017    39
# 2019    38
# 2018    37
# 2016    36
# 2013    36
# 2014    35
# 2015    34
# 2012    30
# 2011    28
# 2010    27
# 2009    24
# 2008    22
# 2002    22
# 2001    22
# 2004    21
# 2003    21
# 2005    20
# 2007    18
# 2006    16
# Name: year, dtype: int64
# 60647.0
# 2019    62
# 2018    55
# 2017    52
# 2016    43
# 2014    42
# 2013    40
# 2012    39
# 2010    38
# 2015    36
# 2011    35
# 2009    31
# 2008    31
# 2007    28
# 2005    27
# 2006    26
# 2002    23
# 2004    22
# 2003    18
# 2001    17
# Name: year, dtype: int64
# 60654.0
# 2019    75
# 2018    73
# 2017    65
# 2015    63
# 2016    60
# 2014    59
# 2013    56
# 2012    41
# 2011    31
# 2010    22
# 2009    12
# 2004     2
# 2008     1
# 2007     1
# 2006     1
# 2005     1
# 2002     1
# 2001     1
# Name: year, dtype: int64
# 60608.0
# 2019    15
# 2018    11
# 2017    11
# 2016    11
# 2015    10
# 2014     9
# 2013     9
# 2011     9
# 2012     8
# 2010     7
# 2009     6
# 2008     6
# 2007     5
# 2006     4
# 2005     4
# 2004     3
# 2003     1
# 2002     1
# Name: year, dtype: int64
# 60630.0
# 2013    5
# 2010    4
# 2014    4
# 2012    4
# 2018    3
# 2006    3
# 2007    3
# 2008    3
# 2009    3
# 2019    3
# 2011    3
# 2015    3
# 2016    3
# 2017    3
# 2005    2
# 2004    2
# 2003    2
# 2002    1
# 2001    1
# Name: year, dtype: int64
# 60661.0
# 2018    29
# 2015    29
# 2019    28
# 2017    28
# 2016    28
# 2014    27
# 2013    27
# 2012    25
# 2011    23
# 2010    20
# 2009    18
# 2008    18
# 2007    11
# 2006    11
# 2001    11
# 2002    10
# 2005     7
# 2004     7
# 2003     6
# Name: year, dtype: int64
# 60611.0
# 2016    96
# 2015    96
# 2014    95
# 2012    94
# 2013    92
# 2018    90
# 2017    90
# 2011    89
# 2019    87
# 2010    83
# 2009    78
# 2007    78
# 2008    76
# 2006    74
# 2005    73
# 2004    68
# 2003    68
# 2002    65
# 2001    61
# Name: year, dtype: int64
# 60614.0
# 2014    88
# 2013    83
# 2015    81
# 2012    81
# 2011    80
# 2009    80
# 2010    78
# 2017    76
# 2016    76
# 2008    75
# 2018    70
# 2006    70
# 2007    69
# 2004    66
# 2019    66
# 2005    65
# 2003    63
# 2002    57
# 2001    49
# Name: year, dtype: int64
# 60610.0
# 2008    105
# 2009    101
# 2007    100
# 2006     92
# 2011     92
# 2010     91
# 2012     91
# 2013     86
# 2005     86
# 2002     84
# 2004     84
# 2003     77
# 2014     73
# 2001     72
# 2015     70
# 2016     70
# 2018     69
# 2017     68
# 2019     60
# Name: year, dtype: int64
# 60622.0
# 2018    103
# 2019    100
# 2017    100
# 2016    100
# 2014     98
# 2015     96
# 2013     94
# 2012     86
# 2011     83
# 2010     75
# 2009     72
# 2008     68
# 2007     61
# 2004     52
# 2006     50
# 2005     48
# 2003     40
# 2002     36
# 2001     28
# Name: year, dtype: int64
# 60657.0
# 2016    117
# 2013    117
# 2017    116
# 2014    116
# 2010    113
# 2012    110
# 2015    109
# 2009    107
# 2011    106
# 2008    103
# 2018    102
# 2019     99
# 2007     97
# 2006     92
# 2005     89
# 2004     87
# 2003     79
# 2001     65
# 2002     64
# Name: year, dtype: int64
# 60641.0
# 2013    13
# 2017    12
# 2012    12
# 2019    11
# 2016    11
# 2018    11
# 2011    10
# 2014     9
# 2008     9
# 2015     8
# 2009     8
# 2007     7
# 2010     7
# 2006     6
# 2005     5
# 2004     4
# 2003     4
# 2002     2
# 2001     1
# Name: year, dtype: int64
# 60707.0
# 2014    4
# 2013    4
# 2012    4
# 2011    4
# 2002    3
# 2016    3
# 2015    3
# 2018    3
# 2010    2
# 2007    2
# 2003    2
# 2005    2
# 2001    2
# 2008    2
# 2009    2
# 2017    2
# 2006    1
# 2004    1
# 2019    1
# Name: year, dtype: int64
# 60615.0
# 2014    13
# 2019    12
# 2017    12
# 2015    10
# 2013    10
# 2016     9
# 2018     8
# 2012     8
# 2011     8
# 2010     7
# 2009     5
# 2008     4
# 2005     3
# 2007     2
# 2006     2
# 2004     2
# 2003     2
# 2002     2
# 2001     2
# Name: year, dtype: int64
# 60642.0
# 2013    28
# 2010    27
# 2011    27
# 2009    23
# 2012    22
# 2014    19
# 2017    18
# 2016    18
# 2008    18
# 2015    17
# 2018    15
# 2003    13
# 2019    12
# 2007    12
# 2006    10
# 2004    10
# 2005     7
# 2002     7
# 2001     6
# Name: year, dtype: int64
# 60607.0
# 2019    87
# 2018    81
# 2017    76
# 2016    74
# 2013    64
# 2015    61
# 2014    59
# 2012    56
# 2011    53
# 2010    49
# 2009    45
# 2008    40
# 2007    36
# 2006    26
# 2005    25
# 2002    22
# 2004    21
# 2001    17
# 2003    16
# Name: year, dtype: int64
# 60660.0
# 2019    28
# 2017    28
# 2018    26
# 2015    24
# 2014    22
# 2016    21
# 2013    21
# 2010    16
# 2012    16
# 2011    15
# 2009    12
# 2008    10
# 2006     6
# 2007     5
# 2002     4
# 2005     3
# 2004     3
# 2003     2
# 2001     1
# Name: year, dtype: int64
# 60618.0
# 2018    50
# 2019    49
# 2014    48
# 2015    47
# 2017    45
# 2011    44
# 2016    43
# 2013    43
# 2012    41
# 2010    40
# 2009    37
# 2007    35
# 2008    33
# 2006    29
# 2004    28
# 2005    27
# 2003    24
# 2002    23
# 2001    16
# Name: year, dtype: int64
# 60603.0
# 2018    24
# 2015    23
# 2017    22
# 2016    22
# 2019    21
# 2014    17
# 2013    17
# 2012    15
# 2008    13
# 2007    12
# 2010    12
# 2011    12
# 2009    11
# 2005    10
# 2004     9
# 2006     8
# 2003     6
# 2002     6
# 2001     4
# Name: year, dtype: int64
# 60623.0
# 2014    2
# 2017    2
# 2013    1
# 2012    1
# 2008    1
# 2007    1
# 2006    1
# 2005    1
# 2004    1
# 2003    1
# 2002    1
# 2001    1
# 2019    1
# 2018    1
# 2016    1
# Name: year, dtype: int64
# 60606.0
# 2017    25
# 2014    25
# 2016    24
# 2015    24
# 2018    23
# 2013    23
# 2019    21
# 2012    21
# 2011    19
# 2010    15
# 2009    12
# 2008    11
# 2005    10
# 2003    10
# 2001     9
# 2007     8
# 2006     8
# 2004     8
# 2002     8
# Name: year, dtype: int64
# 60605.0
# 2014    43
# 2013    42
# 2016    41
# 2015    41
# 2018    39
# 2012    38
# 2017    36
# 2010    33
# 2011    32
# 2009    31
# 2019    31
# 2007    29
# 2008    27
# 2006    19
# 2005    18
# 2004    17
# 2002    13
# 2003    11
# 2001    11
# Name: year, dtype: int64
# 60629.0
# 2018    3
# 2017    3
# 2016    3
# 2015    3
# 2014    3
# 2013    3
# 2012    3
# 2011    3
# 2010    3
# 2009    3
# 2019    2
# 2008    1
# 2005    1
# Name: year, dtype: int64
# 60625.0
# 2007    35
# 2013    35
# 2010    34
# 2017    34
# 2016    34
# 2011    33
# 2014    33
# 2008    33
# 2019    32
# 2012    32
# 2009    29
# 2018    28
# 2015    28
# 2006    28
# 2005    27
# 2004    21
# 2003    17
# 2002    11
# 2001     9
# Name: year, dtype: int64
# 60659.0
# 2012    15
# 2011    14
# 2017    13
# 2016    13
# 2010    11
# 2015    11
# 2014    11
# 2018    11
# 2013     9
# 2008     9
# 2009     8
# 2006     7
# 2002     7
# 2019     7
# 2007     6
# 2001     6
# 2005     5
# 2004     4
# 2003     4
# Name: year, dtype: int64
# 60613.0
# 2013    59
# 2016    58
# 2012    58
# 2017    56
# 2018    56
# 2019    54
# 2006    52
# 2015    52
# 2014    51
# 2004    51
# 2011    50
# 2003    50
# 2010    48
# 2007    48
# 2008    48
# 2005    47
# 2009    47
# 2002    38
# 2001    34
# Name: year, dtype: int64
# 60639.0
# 2019    5
# 2018    4
# 2017    3
# 2016    3
# 2015    3
# 2010    2
# 2005    2
# 2006    2
# 2007    2
# 2011    2
# 2012    2
# 2009    1
# 2008    1
# 2013    1
# 2014    1
# 2004    1
# 2003    1
# Name: year, dtype: int64
# 60619.0
# 2019    1
# Name: year, dtype: int64
# 60609.0
# 2019    3
# 2018    2
# 2015    1
# 2006    1
# 2017    1
# 2003    1
# 2004    1
# 2005    1
# 2007    1
# 2014    1
# 2008    1
# 2009    1
# 2010    1
# 2011    1
# 2012    1
# 2013    1
# 2016    1
# Name: year, dtype: int64
# 60617.0
# 2007    2
# 2015    1
# 2014    1
# 2013    1
# 2012    1
# 2011    1
# 2010    1
# 2009    1
# 2008    1
# 2019    1
# 2018    1
# 2017    1
# Name: year, dtype: int64
# 60616.0
# 2013    18
# 2019    16
# 2016    16
# 2012    16
# 2015    15
# 2014    15
# 2017    14
# 2018    13
# 2010    13
# 2011    12
# 2007    12
# 2009    11
# 2008    10
# 2006     9
# 2005     4
# 2004     3
# 2003     3
# 2002     3
# 2001     2
# Name: year, dtype: int64
# 60653.0
# 2019    3
# 2018    3
# 2011    2
# 2017    2
# 2016    2
# 2015    1
# 2014    1
# 2013    1
# 2012    1
# 2010    1
# 2009    1
# Name: year, dtype: int64
# 60637.0
# 2012    4
# 2015    3
# 2014    3
# 2013    3
# 2011    3
# 2009    2
# 2008    2
# 2007    2
# 2019    2
# 2018    2
# 2016    2
# 2010    1
# 2006    1
# 2017    1
# Name: year, dtype: int64
# 60602.0
# 2013    28
# 2012    28
# 2015    27
# 2014    27
# 2016    25
# 2018    24
# 2017    24
# 2011    23
# 2019    22
# 2010    18
# 2007    17
# 2009    16
# 2008    16
# 2006    13
# 2005    13
# 2004    11
# 2003    10
# 2001     8
# 2002     6
# Name: year, dtype: int64
# 60626.0
# 2011    11
# 2016     9
# 2013     9
# 2012     9
# 2009     8
# 2007     8
# 2014     8
# 2019     7
# 2006     7
# 2008     7
# 2010     7
# 2018     7
# 2017     7
# 2015     6
# 2005     3
# 2004     2
# 2003     2
# 2002     1
# 2001     1
# Name: year, dtype: int64
# 60631.0
# 2011    6
# 2010    6
# 2019    5
# 2014    5
# 2018    4
# 2017    4
# 2016    4
# 2015    4
# 2013    3
# 2012    3
# 2009    3
# 2002    2
# 2004    1
# 2003    1
# 2001    1
# Name: year, dtype: int64
# 60643.0
# 2011    2
# 2010    2
# 2009    2
# 2008    2
# 2006    2
# 2014    1
# 2013    1
# 2012    1
# 2007    1
# 2005    1
# 2002    1
# 2001    1
# 2019    1
# 2018    1
# 2017    1
# 2016    1
# Name: year, dtype: int64
# 60604.0
# 2018    16
# 2017    14
# 2016    14
# 2015    14
# 2019    13
# 2013    13
# 2011    13
# 2014    12
# 2012    12
# 2006     9
# 2010     9
# 2008     8
# 2007     8
# 2009     8
# 2005     8
# 2004     8
# 2003     7
# 2002     4
# 2001     4
# Name: year, dtype: int64
# 60646.0
# 2013    5
# 2012    5
# 2011    5
# 2010    3
# 2006    3
# 2009    3
# 2007    3
# 2004    2
# 2014    2
# 2008    2
# 2003    1
# 2005    1
# 2019    1
# 2018    1
# 2015    1
# 2016    1
# 2002    1
# Name: year, dtype: int64
# 60612.0
# 2019    3
# 2018    3
# 2017    3
# 2015    2
# 2016    2
# 2014    1
# 2012    1
# 2010    1
# 2002    1
# Name: year, dtype: int64
# 60638.0
# 2019    1
# 2018    1
# Name: year, dtype: int64
# 60628.0
# 2018    1
# Name: year, dtype: int64
# 60645.0
# 2007    4
# 2018    3
# 2017    3
# 2016    3
# 2015    3
# 2014    3
# 2012    3
# 2010    3
# 2009    3
# 2008    3
# 2013    2
# 2011    2
# 2006    2
# 2005    2
# 2004    2
# 2003    1
# Name: year, dtype: int64
# 60656.0
# 2008    2
# 2007    2
# 2006    2
# 2013    1
# 2010    1
# 2009    1
# 2005    1
# 2004    1
# 2003    1
# 2002    1
# 2017    1
# 2001    1
# Name: year, dtype: int64
# 60620.0
# 2015    1
# 2016    1
# Name: year, dtype: int64
# 60621.0
# 2014    1
# Name: year, dtype: int64
# 60655.0
# 2014    1
# 2013    1
# Name: year, dtype: int64
# 60632.0
# 2004    1
# 2012    1
# Name: year, dtype: int64
# 60649.0
# 2002    1
# Name: year, dtype: int64

# %%
y=[480, 551, 592, 658, 679, 729, 809, 864, 912, 976, 1037, 1092, 1152, 1139, 1107, 1152, 1165, 1164, 1142]

# %%
x=[2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019]

# %%
plt.plot(x,y)
plt.xticks(x, x, rotation='vertical')
plt.xlabel('Year')
plt.ylabel('Permits')
plt.title('Number of Permits by Year')
plt.show()

# %%
data['year'].value_counts()
# Out:
# 2017    1165
# 2018    1164
# 2016    1152
# 2013    1152
# 2019    1142
# 2014    1139
# 2015    1107
# 2012    1092
# 2011    1037
# 2010     976
# 2009     912
# 2008     864
# 2007     809
# 2006     729
# 2005     679
# 2004     658
# 2003     592
# 2002     551
# 2001     480
# Name: year, dtype: int64

# %%
nbyyear = data.groupby(["ZIP CODE","year"])["year"].count()

# %%
nbyyear
# Out:
# ZIP CODE  year
# 60601.0   2001    22
#           2002    22
#           2003    21
#           2004    21
#           2005    20
#                   ..
# 60707.0   2015     3
#           2016     3
#           2017     2
#           2018     3
#           2019     1
# Name: year, Length: 764, dtype: int64

# %%
x
# Out:
# 22

# %%
fig, ax = plt.subplots(figsize=(15,15))
# use unstack()
data.groupby(["year","ZIP CODE"])['year'].count().unstack().plot(ax=ax)

# %%
|gp.plot()
# Out:
#       PERMIT NUMBER  ACCOUNT NUMBER  ...     Issued month
# year                                 ...
# 2001        1012508           17373  ... 2001-09-17     9
# 2002        1020883          216997  ... 2002-09-11     9
# 2003        1029289          248799  ... 2003-09-05     9
# 2004        1037074          203624  ... 2004-09-29     9
# 2005        1046748          290451  ... 2005-11-15    11
# 2006        1056754           66022  ... 2006-12-06    12
# 2007        1067380          317549  ... 2007-10-31    10
# 2008        1081172          327170  ... 2008-10-16    10
# 2009        1088587          203385  ... 2009-11-16    11
# 2010        1093062          333028  ... 2010-09-10     9
# 2011        1098297           17658  ... 2011-11-01    11
# 2012        1102935          287445  ... 2012-10-02    10
# 2013        1108630          376612  ... 2013-09-19     9
# 2014        1115435           63414  ... 2014-10-15    10
# 2015        1120289           63414  ... 2015-11-09    11
# 2016        1124551          315635  ... 2016-10-05    10
# 2017        1129368          410695  ... 2017-08-31     8
# 2018        1135857          416351  ... 2018-09-24     9
# 2019        1142666          458934  ... 2019-11-25    11
#
# [19 rows x 21 columns]

# %% [markdown]
# It seems as if the number of permits issued grew a lot from 2001 to 2011, and then became somewhat stagnant around 1150 from 2013-2019.

# %%
data['month'] = pd.DatetimeIndex(data['Issued']).month
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
data
# Out:
#        PERMIT NUMBER  ACCOUNT NUMBER  SITE NUMBER  ...     Issued  year month
# 0            1142666          458934            1  ... 2019-11-25  2019    11
# 1            1142290          294900            4  ... 2019-10-15  2019    10
# 2            1142132          459163            1  ... 2019-09-20  2019     9
# 3            1142101          384478            1  ... 2019-09-20  2019     9
# 4            1142100          456144            1  ... 2019-09-19  2019     9
# ...              ...             ...          ...  ...        ...   ...   ...
# 17993        1003612          204664            1  ... 2001-08-01  2001     8
# 17994        1002993              51            1  ... 2001-04-04  2001     4
# 17995        1002652          203574            1  ... 2001-05-07  2001     5
# 17996        1001307          202156            1  ... 2001-06-18  2001     6
# 17997        1000571          201243            1  ... 2001-04-03  2001     4
#
# [17400 rows x 22 columns]

# %%
sns.distplot(data['month'])

# %%
data['month'].value_counts()
# Out:
# 4     5357
# 3     4083
# 5     3930
# 6     1796
# 7      826
# 2      691
# 8      355
# 9      171
# 10      70
# 11      54
# 1       52
# 12      15
# Name: month, dtype: int64

# %% [markdown]
# The most popular time to issue a permit was in the spring months- April, March, May, then June. After that, the number decreases notably.

# %%
data['ZIP CODE'].value_counts()
# Out:
# 60657.0    1888
# 60610.0    1571
# 60611.0    1553
# 60622.0    1390
# 60614.0    1373
# 60613.0     957
# 60607.0     908
# 60618.0     702
# 60640.0     669
# 60647.0     665
# 60654.0     565
# 60605.0     552
# 60625.0     533
# 60601.0     526
# 60661.0     363
# 60602.0     356
# 60642.0     309
# 60606.0     304
# 60603.0     264
# 60660.0     263
# 60616.0     205
# 60604.0     194
# 60659.0     171
# 60641.0     150
# 60608.0     130
# 60634.0     129
# 60615.0     121
# 60626.0     119
# 60630.0      55
# 60631.0      52
# 60707.0      47
# 60645.0      42
# 60646.0      40
# 60639.0      36
# 60629.0      34
# 60637.0      31
# 60643.0      21
# 60609.0      20
# 60653.0      18
# 60623.0      17
# 60612.0      17
# 60656.0      15
# 60617.0      13
# 60655.0       2
# 60620.0       2
# 60638.0       2
# 60632.0       2
# 60619.0       1
# 60649.0       1
# 60621.0       1
# 60628.0       1
# Name: ZIP CODE, dtype: int64

# %%
df = data['ZIP CODE'].value_counts().rename_axis('Zipcode').reset_index(name='cafe_permits')
print (df)
# Out:
#     Zipcode  cafe_permits
# 0   60657.0          1888
# 1   60610.0          1571
# 2   60611.0          1553
# 3   60622.0          1390
# 4   60614.0          1373
# 5   60613.0           957
# 6   60607.0           908
# 7   60618.0           702
# 8   60640.0           669
# 9   60647.0           665
# 10  60654.0           565
# 11  60605.0           552
# 12  60625.0           533
# 13  60601.0           526
# 14  60661.0           363
# 15  60602.0           356
# 16  60642.0           309
# 17  60606.0           304
# 18  60603.0           264
# 19  60660.0           263
# 20  60616.0           205
# 21  60604.0           194
# 22  60659.0           171
# 23  60641.0           150
# 24  60608.0           130
# 25  60634.0           129
# 26  60615.0           121
# 27  60626.0           119
# 28  60630.0            55
# 29  60631.0            52
# 30  60707.0            47
# 31  60645.0            42
# 32  60646.0            40
# 33  60639.0            36
# 34  60629.0            34
# 35  60637.0            31
# 36  60643.0            21
# 37  60609.0            20
# 38  60653.0            18
# 39  60623.0            17
# 40  60612.0            17
# 41  60656.0            15
# 42  60617.0            13
# 43  60655.0             2
# 44  60620.0             2
# 45  60638.0             2
# 46  60632.0             2
# 47  60619.0             1
# 48  60649.0             1
# 49  60621.0             1
# 50  60628.0             1

# %% [markdown]
# I wanted to see which neighborhoods have the most sidewalk cafes. I actually live in 60657, and can attest to how many sidewalk cafes there are on my local streets, but didn't know we had the most in the city. I would like to group all of these zipcodes by 'neighborhood' and perform further analysis on these, and whether these restaurants are repeat permit renewers.

# %%
# !pip install geopandas
# Out:
# Collecting geopandas
#   Downloading https://files.pythonhosted.org/packages/83/c5/3cf9cdc39a6f2552922f79915f36b45a95b71fd343cfc51170a5b6ddb6e8/geopandas-0.7.0-py2.py3-none-any.whl (928kB)
#      |████████████████████████████████| 931kB 2.8MB/s
# Collecting pyproj>=2.2.0
#   Downloading https://files.pythonhosted.org/packages/77/15/d93f446d253d26b91553f86cf21049183e9b0f51f8c8e6cb2cff081bcc02/pyproj-2.5.0-cp36-cp36m-manylinux2010_x86_64.whl (10.4MB)
#      |████████████████████████████████| 10.4MB 52.1MB/s
# Requirement already satisfied: pandas>=0.23.0 in /usr/local/lib/python3.6/dist-packages (from geopandas) (0.25.3)
# Collecting fiona
#   Downloading https://files.pythonhosted.org/packages/ec/20/4e63bc5c6e62df889297b382c3ccd4a7a488b00946aaaf81a118158c6f09/Fiona-1.8.13.post1-cp36-cp36m-manylinux1_x86_64.whl (14.7MB)
#      |████████████████████████████████| 14.7MB 311kB/s
# Requirement already satisfied: shapely in /usr/local/lib/python3.6/dist-packages (from geopandas) (1.7.0)
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.6/dist-packages (from pandas>=0.23.0->geopandas) (2018.9)
# Requirement already satisfied: numpy>=1.13.3 in /usr/local/lib/python3.6/dist-packages (from pandas>=0.23.0->geopandas) (1.17.5)
# Requirement already satisfied: python-dateutil>=2.6.1 in /usr/local/lib/python3.6/dist-packages (from pandas>=0.23.0->geopandas) (2.6.1)
# Requirement already satisfied: six>=1.7 in /usr/local/lib/python3.6/dist-packages (from fiona->geopandas) (1.12.0)
# Collecting munch
#   Downloading https://files.pythonhosted.org/packages/cc/ab/85d8da5c9a45e072301beb37ad7f833cd344e04c817d97e0cc75681d248f/munch-2.5.0-py2.py3-none-any.whl
# Requirement already satisfied: attrs>=17 in /usr/local/lib/python3.6/dist-packages (from fiona->geopandas) (19.3.0)
# Collecting click-plugins>=1.0
#   Downloading https://files.pythonhosted.org/packages/e9/da/824b92d9942f4e472702488857914bdd50f73021efea15b4cad9aca8ecef/click_plugins-1.1.1-py2.py3-none-any.whl
# Requirement already satisfied: click<8,>=4.0 in /usr/local/lib/python3.6/dist-packages (from fiona->geopandas) (7.0)
# Collecting cligj>=0.5
#   Downloading https://files.pythonhosted.org/packages/e4/be/30a58b4b0733850280d01f8bd132591b4668ed5c7046761098d665ac2174/cligj-0.5.0-py3-none-any.whl
# Installing collected packages: pyproj, munch, click-plugins, cligj, fiona, geopandas
# Successfully installed click-plugins-1.1.1 cligj-0.5.0 fiona-1.8.13.post1 geopandas-0.7.0 munch-2.5.0 pyproj-2.5.0

# %%
import geopandas as gpd

# %%
# set the filepath and load in a shapefile
#fp = “content/drive/My Drive/chicagoboundaries.shp”
map_df = gpd.read_file('/content/drive/My Drive/Boundaries.geojson')
# check data type so we can see that this is not a normal dataframe, but a GEOdataframe
map_df.head()
# Out:
#   objectid  ...                                           geometry
# 0       33  ...  MULTIPOLYGON (((-87.67762 41.91776, -87.67761 ...
# 1       34  ...  MULTIPOLYGON (((-87.72683 41.92265, -87.72693 ...
# 2       35  ...  MULTIPOLYGON (((-87.78500 41.90915, -87.78531 ...
# 3       36  ...  MULTIPOLYGON (((-87.66707 41.88885, -87.66707 ...
# 4       37  ...  MULTIPOLYGON (((-87.70656 41.89555, -87.70672 ...
#
# [5 rows x 5 columns]

# %%
map_df['zip']
# Out:
# 0     60647
# 1     60639
# 2     60707
# 3     60622
# 4     60651
#       ...
# 56    60623
# 57    60629
# 58    60620
# 59    60637
# 60    60619
# Name: zip, Length: 61, dtype: object

# %%
map_df.plot()

# %%
mapdata=pd.DataFrame(df)

# %%
ziptest2 = mapdata.astype('int64', copy=False)

# %%
ziptest2
# Out:
#     Zipcode  cafe_permits
# 0     60657          1888
# 1     60610          1571
# 2     60611          1553
# 3     60622          1390
# 4     60614          1373
# 5     60613           957
# 6     60607           908
# 7     60618           702
# 8     60640           669
# 9     60647           665
# 10    60654           565
# 11    60605           552
# 12    60625           533
# 13    60601           526
# 14    60661           363
# 15    60602           356
# 16    60642           309
# 17    60606           304
# 18    60603           264
# 19    60660           263
# 20    60616           205
# 21    60604           194
# 22    60659           171
# 23    60641           150
# 24    60608           130
# 25    60634           129
# 26    60615           121
# 27    60626           119
# 28    60630            55
# 29    60631            52
# 30    60707            47
# 31    60645            42
# 32    60646            40
# 33    60639            36
# 34    60629            34
# 35    60637            31
# 36    60643            21
# 37    60609            20
# 38    60653            18
# 39    60623            17
# 40    60612            17
# 41    60656            15
# 42    60617            13
# 43    60655             2
# 44    60620             2
# 45    60638             2
# 46    60632             2
# 47    60619             1
# 48    60649             1
# 49    60621             1
# 50    60628             1

# %%
map_df['zip']=map_df['zip'].astype('int64', copy=False)

# %%
map_df
# Out:
#    objectid  ...                                           geometry
# 0        33  ...  MULTIPOLYGON (((-87.67762 41.91776, -87.67761 ...
# 1        34  ...  MULTIPOLYGON (((-87.72683 41.92265, -87.72693 ...
# 2        35  ...  MULTIPOLYGON (((-87.78500 41.90915, -87.78531 ...
# 3        36  ...  MULTIPOLYGON (((-87.66707 41.88885, -87.66707 ...
# 4        37  ...  MULTIPOLYGON (((-87.70656 41.89555, -87.70672 ...
# ..      ...  ...                                                ...
# 56       57  ...  MULTIPOLYGON (((-87.69479 41.83008, -87.69486 ...
# 57       58  ...  MULTIPOLYGON (((-87.68306 41.75786, -87.68306 ...
# 58       59  ...  MULTIPOLYGON (((-87.62373 41.72167, -87.62388 ...
# 59       60  ...  MULTIPOLYGON (((-87.57691 41.79511, -87.57700 ...
# 60       61  ...  MULTIPOLYGON (((-87.58592 41.75150, -87.58592 ...
#
# [61 rows x 5 columns]

# %%
merged = (ziptest2.set_index('Zipcode')).join(map_df.set_index('zip'))
merged
# Out:
#         cafe_permits objectid shape_area shape_len geometry
# 60601.0          526      NaN        NaN       NaN     None
# 60602.0          356      NaN        NaN       NaN     None
# 60603.0          264      NaN        NaN       NaN     None
# 60604.0          194      NaN        NaN       NaN     None
# 60605.0          552      NaN        NaN       NaN     None
# 60606.0          304      NaN        NaN       NaN     None
# 60607.0          908      NaN        NaN       NaN     None
# 60608.0          130      NaN        NaN       NaN     None
# 60609.0           20      NaN        NaN       NaN     None
# 60610.0         1571      NaN        NaN       NaN     None
# 60611.0         1553      NaN        NaN       NaN     None
# 60612.0           17      NaN        NaN       NaN     None
# 60613.0          957      NaN        NaN       NaN     None
# 60614.0         1373      NaN        NaN       NaN     None
# 60615.0          121      NaN        NaN       NaN     None
# 60616.0          205      NaN        NaN       NaN     None
# 60617.0           13      NaN        NaN       NaN     None
# 60618.0          702      NaN        NaN       NaN     None
# 60619.0            1      NaN        NaN       NaN     None
# 60620.0            2      NaN        NaN       NaN     None
# 60621.0            1      NaN        NaN       NaN     None
# 60622.0         1390      NaN        NaN       NaN     None
# 60623.0           17      NaN        NaN       NaN     None
# 60625.0          533      NaN        NaN       NaN     None
# 60626.0          119      NaN        NaN       NaN     None
# 60628.0            1      NaN        NaN       NaN     None
# 60629.0           34      NaN        NaN       NaN     None
# 60630.0           55      NaN        NaN       NaN     None
# 60631.0           52      NaN        NaN       NaN     None
# 60632.0            2      NaN        NaN       NaN     None
# 60634.0          129      NaN        NaN       NaN     None
# 60637.0           31      NaN        NaN       NaN     None
# 60638.0            2      NaN        NaN       NaN     None
# 60639.0           36      NaN        NaN       NaN     None
# 60640.0          669      NaN        NaN       NaN     None
# 60641.0          150      NaN        NaN       NaN     None
# 60642.0          309      NaN        NaN       NaN     None
# 60643.0           21      NaN        NaN       NaN     None
# 60645.0           42      NaN        NaN       NaN     None
# 60646.0           40      NaN        NaN       NaN     None
# 60647.0          665      NaN        NaN       NaN     None
# 60649.0            1      NaN        NaN       NaN     None
# 60653.0           18      NaN        NaN       NaN     None
# 60654.0          565      NaN        NaN       NaN     None
# 60655.0            2      NaN        NaN       NaN     None
# 60656.0           15      NaN        NaN       NaN     None
# 60657.0         1888      NaN        NaN       NaN     None
# 60659.0          171      NaN        NaN       NaN     None
# 60660.0          263      NaN        NaN       NaN     None
# 60661.0          363      NaN        NaN       NaN     None
# 60707.0           47      NaN        NaN       NaN     None

# %%
merged_left = pd.merge(left=map_df, right=ziptest2, how='right', left_on='zip', right_on='Zipcode')
merged_left
# Out:
#    objectid     shape_area  ... Zipcode  cafe_permits
# 0        33  106052287.488  ...   60647           665
# 1        34  127476050.762  ...   60639            36
# 2        35  45069038.4783  ...   60707            47
# 3        51  3450671.14336  ...   60707            47
# 4        36  70853834.3797  ...   60622          1390
# 5        38  23506055.7304  ...   60611          1553
# 6        39  166166339.096  ...   60638             2
# 7         1  49170578.9623  ...   60626           119
# 8         8  66565454.8469  ...   60615           121
# 9         9  104746821.074  ...   60621             1
# 10        2  62181473.5197  ...   60645            42
# 11       13  183013076.262  ...   60643            21
# 12       15  3136688.22496  ...   60643            21
# 13        3  37984388.8422  ...   60660           263
# 14        4  77305245.7089  ...   60640           669
# 15       32  94460631.8068  ...   60614          1373
# 16       41   107117591.88  ...   60631            52
# 17       42  117890054.124  ...   60646            40
# 18       43  345241692.171  ...   60628             1
# 19        5  105830918.023  ...   60625           533
# 20        6  113903341.112  ...   60641           150
# 21        7  63547755.9216  ...   60657          1888
# 22       11  80526076.0889  ...   60649             1
# 23       12  452837422.002  ...   60617            13
# 24       16  106718949.386  ...   60612            17
# 25       48  4294901.99439  ...   60604           194
# 26       47   89515884.463  ...   60656            15
# 27       49  115380139.149  ...   60655             2
# 28       19  4560228.98203  ...   60603           264
# 29       20  36301276.3485  ...   60605           552
# 30       21  67759827.8103  ...   60653            18
# 31       22  213490325.264  ...   60609            20
# 32       24  141235867.545  ...   60618           702
# 33       25  109667069.368  ...   60616           205
# 34       26   4847124.8171  ...   60602           356
# 35       27  9166245.79985  ...   60601           526
# 36       28  176505462.522  ...   60608           130
# 37       29  64664293.9426  ...   60607           908
# 38       30  9357755.68017  ...   60661           363
# 39       31  6766410.89809  ...   60606           304
# 40       45   131073763.12  ...   60630            55
# 41       46     47961494.4  ...   60642           309
# 42       50  69698411.4356  ...   60659           171
# 43       52  194062612.162  ...   60634           129
# 44       53  53990894.8848  ...   60613           957
# 45       54  31598157.0867  ...   60610          1571
# 46       55  15869961.3469  ...   60654           565
# 47       56  211755252.573  ...   60632             2
# 48       57  155285532.005  ...   60623            17
# 49       58  211114779.439  ...   60629            34
# 50       59  211696050.967  ...   60620             2
# 51       60  125424284.172  ...   60637            31
# 52       61  167872012.644  ...   60619             1
#
# [53 rows x 7 columns]

# %%
(column=variable, cmap=’Blues’, linewidth=0.8, ax=ax, edgecolor=’0.8')

# %%
map_df['zip']
# Out:
# 0     60647
# 1     60639
# 2     60707
# 3     60622
# 4     60651
#       ...
# 56    60623
# 57    60629
# 58    60620
# 59    60637
# 60    60619
# Name: zip, Length: 61, dtype: object

# %%
import matplotlib.pyplot as plt

# %%
# set a variable that will call whatever column we want to visualise on the map
variable = 'cafe_permits'
# set the range for the choropleth
vmin, vmax = 120, 220
# create figure and axes for Matplotlib
fig, ax = plt.subplots(1, figsize=(15, 10))
merged_left.plot(column=variable, cmap='Blues', linewidth=0.8, ax=ax, edgecolor='0.8')
sm = plt.cm.ScalarMappable(cmap='Blues', norm=plt.Normalize(vmin=vmin, vmax=vmax))
# empty array for the data range
sm._A = []
# add the colorbar to the figure
cbar = fig.colorbar(sm)
# add a title
ax.set_title('Sidewalk Cafe Permits in Chicago', fontdict={'fontsize': '25', 'fontweight' : '3'})
# create an annotation for the data source
ax.annotate('Source: City of Chicago',xy=(.35, .05),  xycoords='figure fraction', horizontalalignment='left', verticalalignment='top', fontsize=12, color='#555555')
# Out:
# Text(0.35, 0.05, 'Source: City of Chicago')

# %%
sm = plt.cm.ScalarMappable(cmap='Blues', norm=plt.Normalize(vmin=vmin, vmax=vmax))
# empty array for the data range
sm._A = []
# add the colorbar to the figure
cbar = fig.colorbar(sm)

# %%
merged

# %%
data['ACCOUNT NUMBER'].value_counts().head(40)
# Out:
# 63414     790
# 65004     253
# 298727    108
# 50161      67
# 22633      61
# 230211     60
# 17658      48
# 66022      45
# 267891     45
# 207283     43
# 86212      37
# 85312      37
# 369504     35
# 207993     33
# 269555     31
# 290569     30
# 5948       29
# 269043     29
# 22622      27
# 2962       26
# 5466       26
# 331323     25
# 254059     24
# 10057      24
# 14172      23
# 85630      21
# 3066       21
# 210267     20
# 5350       20
# 64797      20
# 9454       20
# 3085       19
# 17500      19
# 23957      19
# 242        19
# 11179      19
# 4488       19
# 8020       19
# 14614      19
# 63726      19
# Name: ACCOUNT NUMBER, dtype: int64

# %%
data[data['ACCOUNT NUMBER']==17500]
# Out:
#        PERMIT NUMBER  ACCOUNT NUMBER  SITE NUMBER  ...     Issued  year month
# 996          1137849           17500            1  ... 2019-02-26  2019     2
# 2146         1131501           17500            1  ... 2018-04-06  2018     4
# 3463         1126077           17500            1  ... 2017-03-30  2017     3
# 4621         1121614           17500            1  ... 2016-03-08  2016     3
# 5475         1117551           17500            1  ... 2015-04-14  2015     4
# 6741         1111577           17500            1  ... 2014-03-24  2014     3
# 8234         1104564           17500            1  ... 2013-03-29  2013     3
# 9375         1099587           17500            1  ... 2012-03-08  2012     3
# 9859         1096093           17500            1  ... 2011-04-21  2011     4
# 11476        1089826           17500            1  ... 2010-03-05  2010     3
# 12140        1086245           17500            1  ... 2009-03-30  2009     3
# 12945        1073589           17500            1  ... 2008-04-04  2008     4
# 13410        1062701           17500            1  ... 2007-05-16  2007     5
# 14559        1050148           17500            1  ... 2006-04-26  2006     4
# 15462        1041984           17500            1  ... 2005-04-22  2005     4
# 16020        1033233           17500            1  ... 2004-04-13  2004     4
# 16464        1026825           17500            1  ... 2003-06-23  2003     6
# 17260        1016660           17500            1  ... 2002-04-19  2002     4
# 17717        1009335           17500            1  ... 2001-05-22  2001     5
#
# [19 rows x 22 columns]

# %%
data[data['ACCOUNT NUMBER']==65004]
# Out:
#        PERMIT NUMBER  ACCOUNT NUMBER  SITE NUMBER  ...     Issued  year month
# 1055         1137736           65004           29  ... 2019-03-08  2019     3
# 1056         1137735           65004            1  ... 2019-03-08  2019     3
# 1057         1137734           65004           12  ... 2019-03-08  2019     3
# 1058         1137733           65004           11  ... 2019-03-08  2019     3
# 1059         1137732           65004           13  ... 2019-03-08  2019     3
# ...              ...             ...          ...  ...        ...   ...   ...
# 16209        1032600           65004           10  ... 2004-03-30  2004     3
# 16324        1028470           65004           15  ... 2003-08-01  2003     8
# 16848        1025312           65004            1  ... 2003-04-29  2003     4
# 16944        1021741           65004           10  ... 2003-04-29  2003     4
# 17819        1008795           65004            1  ... 2001-04-12  2001     4
#
# [253 rows x 22 columns]

# %%
#Data Dictionary
print('Number of unique permit numbers:',data['permit'].nunique())
print('Number of unique account numbers:',data['account'].nunique(dropna='TRUE'))
print('Site Numbers:',data['site'].unique())
print('Number of legal names:',data['legname'.nunique())
print('Number of business names:',busname.nunique()) 
print('Number of issued dates:',issdate.nunique(dropna='TRUE'))
print('Expiration dates:',expdate.unique())
print('Number of payment dates:',paydate.nunique())
print('Number of addresses:',address.nunique())
print('Street direction:', stdir.unique())
print('Street name:', street.unique())
print('Street type:', sttype.unique())
print('City:',city.unique())
print('State:',state.unique())
print('Zip Code:',zipcode.unique())
print('Ward:',ward.unique())
print('Precinct:',precinct.unique())
print('Number of ward-precincts:', wardprec.nunique())
print('Police District:',police.unique())
print('Number of Community Areas:',community.unique())
#The rest of the variables are not relevant to this project.
